# %%
import os
os.chdir(r'\\share.ipp-hgw.mpg.de\documents\pih\Documents\git\QSB_Bolometry\libprad')

import importlib
import archivedb

import numpy as np
from scipy.spatial import HalfspaceIntersection
from scipy.spatial import ConvexHull

import matplotlib as mpl
import matplotlib.pyplot as p
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Polygon
from matplotlib.pyplot import cm
import plotly.graph_objects as go
from matplotlib.collections import PatchCollection

import plot_funcs as pf
import invert_main as invert
import mfr2D_matrix_gridtransform as grid_transf
import phantom_methods as pm
import factors_geometry_plots as fgp
import LoS_volume as vol

import mfr2D_accessoires as mfr2D
import phantom_metrics as phm
import mfr_phantoms as mfrp
import phantom_comparison as phanc
import mfr_plot

import thomson_scattering as TS
import importlib
import thomsonS_access as TA
import TS_to_json as TJ
import plot_funcs as pf

import factors_geometry_plots as fgp
import profile_to_lint as ptl

import poincare
import poincare_plots

import webapi_access as api
# program = '20181010.032'
# program_info, req = api.xpid_info(program=program)

import dat_lists as lists
camera_info = lists.geom_dat_to_json()

# t0 = program_info['programs'][0][
#     'trigger']['1'][0]  # in ns
# t4 = program_info['programs'][0][
#     'trigger']['4'][0]  # in ns

# %%
nPhi = 30  # toroidal slices
nFS = 20  # radial slices
nL = 150 # 150  # poloidal slices
vpF = 1.35  # blowup from LCFS
magconf = 'EIM_000'  # magnetic configuration

# %%
N = [1, 2]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
#  emissivity2D, emissivity3D, factors, reff, pos_lofs,
#  minor_radius, reff_LoS, geometry, interpolated, LoS, label
standard_sN2 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = 2  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'triang'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
standard_tN2 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = 4  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'triang'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
standard_tN4 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = [2, 2]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
standard_sN4 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = 8  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'triang'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
standard_tN8 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = [2, 4]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
#  emissivity2D, emissivity3D, factors, reff, pos_lofs,
#  minor_radius, reff_LoS, geometry, interpolated, LoS, label
standard_sN8 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)
# Out:
# \\ strgrid sN8_30x20x150_1.35 confstr EIM_beta000_sN8_30x20x150_1.35
# 	Creating fluxsurface library for EIM_beta000
#                 FLUXSURFACE: beta-scan with bell-shaped pressure profile ~ (1-s)^2; peaking
#                              factor = 3; runs with _l6ns151 have an enlarged volume - cover
#                              island region EIM configuration (ref. configuration A: standard,
#                              planned OP1.2 configuration). Flux surface geometry of EIM
#                              configuration corresponds to the experimental EJM configuration
# 		Loading from: EIM_beta000_fs_data.json
# 		Splitting detectors and slit 2x4 times
# 		>> End result supposed to have 8 squares
# 	Constructing lines of sight...
# 		\\ load xy slope  (128, 64) 0.06MB
# 		\\ load xy constant  (128, 64) 0.06MB
# 		\\ load xy range  (128, 64, 2) 0.13MB
# 		\\ load xy line  (128, 64, 2) 0.13MB
# 		\\ load xz slope  (128, 64) 0.06MB
# 		\\ load xz constant  (128, 64) 0.06MB
# ...

# %%
N = [2, 8]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
standard_sN16 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = 16  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'triang'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
standard_tN16 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = [2, 4]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
artificialHBCm_sN8 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=True,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = [2, 4]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
centered_sN8 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=True,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = [2, 4]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
fixedLos_sN8 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=True,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = [2, 4]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)
# raw_volume, old_volume, volume, line_sections2D, line_sections3D,
# emissivity2D, emissivity3D, factors, reff, pos_lofs,
# minor_radius, reff_LoS, geometry, interpolated, LoS, label
symmetric_sN8 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type=None,  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=True,
    tilt=False,
    plot=False,
    debug=False)

# %%
N = [2, 4]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)

tilted_sN8 = []
for tilt in [-3., 3.]:  # -2., -1., 1., 2., 3.]:
    # (raw_volume, old_volume, volume, line_sections2D, line_sections3D,
    # emissivity2D, emissivity3D, factors, reff, pos_lofs,
    # minor_radius, reff_LoS, geometry, interpolated, LoS, label)
    tilted_sN8.append(invert.main(
        nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
        VMID=magconf, interp_method=interpolation,
        tilt_deg=tilt, error_scale=0.0001,  # 0.1 mm (0.5 mm)  
        add_camera=False,
        new_type=None,  # 'HBCm', 'VBCh'
        artificial_HBCm=False,
        random_error=False,
        centered=False,
        fix_LoS=False,
        symmetric=False,
        tilt=True,
        plot=False,
        debug=False))

# %%
N = [2, 4]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

importlib.reload(invert)

errors_sN8 = []
for error in [0.0001, 0.0005, 0.001]:
    # (raw_volume, old_volume, volume, line_sections2D, line_sections3D,
    # emissivity2D, emissivity3D, factors, reff, pos_lofs,
    # minor_radius, reff_LoS, geometry, interpolated, LoS, label)
    errors_sN8.append(invert.main(
        nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
        VMID=magconf, interp_method=interpolation,
        tilt_deg=1., error_scale=error,  # 0.1 mm (0.5 mm)  
        add_camera=False,
        new_type=None,  # 'HBCm', 'VBCh'
        artificial_HBCm=False,
        random_error=True,
        centered=False,
        fix_LoS=False,
        symmetric=False,
        tilt=False,
        plot=False,
        debug=False))

# %%
N = [2, 4]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

artificials_sN8 = []
importlib.reload(invert)
for camera in ['MIRh', 'VBCm']:
    # (raw_volume, old_volume, volume, line_sections2D, line_sections3D,
    # emissivity2D, emissivity3D, factors, reff, pos_lofs,
    # minor_radius, reff_LoS, geometry, interpolated, LoS, label) =
    artificials_sN8.append(invert.main(
        nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
        VMID=magconf, interp_method=interpolation,
        tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
        add_camera=True,
        new_type=camera,  # 'HBCm', 'VBCh'
        artificial_HBCm=False,
        random_error=False,
        centered=False,
        fix_LoS=False,
        symmetric=False,
        tilt=False,
        plot=False,
        debug=False))
# Out:
# \\ strgrid sN8_30x20x150_1.35 confstr EIM_beta000_sN8_30x20x150_1.35
# 	Creating fluxsurface library for EIM_beta000
#                 FLUXSURFACE: beta-scan with bell-shaped pressure profile ~ (1-s)^2; peaking
#                              factor = 3; runs with _l6ns151 have an enlarged volume - cover
#                              island region EIM configuration (ref. configuration A: standard,
#                              planned OP1.2 configuration). Flux surface geometry of EIM
#                              configuration corresponds to the experimental EJM configuration
# 		Loading from: EIM_beta000_fs_data.json
# 		Setting up new camera: MIRh (12 ch)...
# 		Splitting detectors and slit 2x4 times
# 		>> End result supposed to have 8 squares
# 	Constructing lines of sight...
# 		\\ load xy slope  (128, 64) 0.06MB
# 		\\ load xy constant  (128, 64) 0.06MB
# 		\\ load xy range  (128, 64, 2) 0.13MB
# 		\\ load xy line  (128, 64, 2) 0.13MB
# 		\\ load xz slope  (128, 64) 0.06MB
# ...

# %%
N = [2, 4]  # [2, 4]  # detector seperation, short X long side, 8
nN = N[0] * N[1] if isinstance(N, list) else N
interpolation = 'square'  # 'square'  # detector split mode (triang)

strgrid = interpolation[0] + 'N' + str(nN) + '_' + \
          str(nPhi) + 'x' + str(nFS) + 'x' + str(nL) + '_' + str(vpF) 
confstr = magconf[:4] + 'beta' + magconf[-3:] + '_' + interpolation[0] + \
          'N' + str(nN) + '_' + str(nPhi) + 'x' + str(nFS) + \
          'x' + str(nL) + '_' + str(vpF)
print('\\\ strgrid ' + strgrid + ' confstr ' + confstr)

mesh2D, mesh3D = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=N, 
    VMID=magconf, interp_method=interpolation,
    tilt_deg=1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type='None',  # 'HBCm', 'VBCh'
    artificial_HBCm=False,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)[:2]

# %%
importlib.reload(vol)
importlib.reload(invert)
raw_CvH_2_15, full_CvH_2_15 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=[1, 2], 
    VMID=magconf, interp_method='square',
    tilt_deg=1., error_scale=0.0001,
    add_camera=False, new_type='None', artificial_HBCm=False,
    random_error=False, centered=False, fix_LoS=False, symmetric=False,
    tilt=False, plot=False, debug=False)

# %%
importlib.reload(vol)
importlib.reload(invert)
raw_CvH_8_15, full_CvH_8_15 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=[2, 4], 
    VMID=magconf, interp_method='square',
    tilt_deg=1., error_scale=0.0001,
    add_camera=False, new_type='None', artificial_HBCm=False,
    random_error=False, centered=False, fix_LoS=False, symmetric=False,
    tilt=False, plot=False, debug=False)

# %%
importlib.reload(vol)
importlib.reload(invert)
raw_CvH_8_16, full_CvH_8_16 = invert.main(
    nPhi=nPhi, nL=nL, nFS=nFS, vpF=vpF, N=[2, 4], 
    VMID=magconf, interp_method='square',
    tilt_deg=1., error_scale=0.0001,
    add_camera=False, new_type='None', artificial_HBCm=False,
    random_error=False, centered=False, fix_LoS=False, symmetric=False,
    tilt=False, plot=False, debug=False)

# %%
fig = p.figure()
ax = Axes3D(fig)

for i in range(30):
    p.plot(
        mesh3D[0, i, 20, :],
        mesh3D[1, i, 20, :],
        mesh3D[2, i, 20, :],
        c='lightgrey', alpha=0.5, lw=0.5)

for i in range(151):
    p.plot(
        mesh3D[0, :, 20, i],
        mesh3D[1, :, 20, i],
        mesh3D[2, :, 20, i],
        c='lightgrey', alpha=0.5, lw=0.5)

for c, CvH in zip(['r', 'b'],
                  [full_CvH_8, raw_CvH_8]):

    if CvH.__class__ != list:
        CvH = [CvH]

    for CH in CvH:
        CvxH = ConvexHull(CH)
        faces = CvxH.simplices

        for simplex in faces:
            X, Y, Z = CH[simplex, 0], CH[simplex, 1], \
                CH[simplex, 2]
            vertices = [list(zip(X, Y, Z))]

            LoS = Poly3DCollection(vertices)
            LoS.set_color(c)
            LoS.set_alpha(0.4)
            LoS.set_edgecolor(c)
            LoS.set_facecolor(c)
            LoS.set_linewidth(0.0)
            ax.add_collection(LoS)

ax.set_xlim(np.min(mesh3D[0, :, 20, :]), np.max(mesh3D[0, :, 20, :]))
ax.set_ylim(np.min(mesh3D[1, :, 20, :]), np.max(mesh3D[1, :, 20, :]))
ax.set_zlim(np.min(mesh3D[2, :, 20, :]), np.max(mesh3D[2, :, 20, :]))

ax.axis('off')
ax.grid(b=None)
ax.view_init(40., 60.)

fig.set_size_inches(5., 4.)
fig.savefig('viewcones_ch15_sN8.pdf', dpi=169., bbox_inches='tight')
p.close('all')

# %%
order = (1, 2, 3, 4, 1)
orderT = (1, 2, 3, 1)

detectors = np.array([
    standard_sN2[12]['values']['x'],
    standard_sN2[12]['values']['y'],
    standard_sN2[12]['values']['z']])

fig = p.figure()
ax_sN2 = fig.add_subplot(3, 2, 1, projection='3d')
ax_tN2 = fig.add_subplot(3, 2, 2, projection='3d')
ax_sN4 = fig.add_subplot(3, 2, 3, projection='3d')
ax_tN4 = fig.add_subplot(3, 2, 4, projection='3d')
ax_sN8 = fig.add_subplot(3, 2, 5, projection='3d')
ax_tN8 = fig.add_subplot(3, 2, 6, projection='3d')

axes = [ax_sN2, ax_tN2, ax_sN4, ax_tN4, ax_sN8, ax_tN8]
titles = ['interpolation, N=2', 'triangulation, N=2',
          'interpolation, N=4', 'triangulation, N=4',
          'interpolation, N=8', 'triangulation, N=8']

for i, ax in enumerate(axes):
    ax.plot(
        [detectors[0, 0, 0]], [detectors[1, 0, 0]], [detectors[2, 0, 0]],
        c='k', marker='x', markersize=6., alpha=.75)
    ax.plot(
        detectors[0, 0, order], detectors[1, 0, order], detectors[2, 0, order],
        c='k', marker='^', markersize=5., lw=1., alpha=.75)

    interpolated = np.array([
        data[i][13]['values']['x'],
        data[i][13]['values']['y'],
        data[i][13]['values']['z']])

    N, T = np.shape(interpolated)[2:]
    colors = cm.brg(np.linspace(.0, 1., N))

    O = (1, 3, 4, 2, 1) if T > 4 else orderT
    for j in range(N):
        ax.plot(  # square/triangle
            interpolated[0, 0, j, O],
            interpolated[1, 0, j, O],
            interpolated[2, 0, j, O],
            c=colors[j], lw=1., alpha=0.75,
            marker='v', markersize=5.)
        ax.plot(  # center
            [interpolated[0, 0, j, 0]],
            [interpolated[1, 0, j, 0]],
            [interpolated[2, 0, j, 0]],
            c=colors[j], alpha=0.75,
            marker='x', markersize=5.)

for i, ax in enumerate(axes):
    ax.axis('off')
    ax.grid(b=None)
    # ax.view_init(70., -70.)

    ax.set_title(titles[i])
    ax.axes.xaxis.set_ticklabels([])
    ax.axes.yaxis.set_ticklabels([])
    ax.axes.zaxis.set_ticklabels([])

    ax.set_xlim(np.min(detectors[0, 0]), np.max(detectors[0, 0]))
    ax.set_ylim(np.min(detectors[1, 0]), np.max(detectors[1, 0]))
    ax.set_zlim(np.min(detectors[2, 0]), np.max(detectors[2, 0]))

fig.set_size_inches(10., 8.)
fig.savefig('detector_splitting.pdf', dpi=169., bbox_inches='tight')
p.close('all')

# %%
# data = [standard_sN2, standard_tN2,
#         standard_sN4, standard_tN4,
#         standard_sN8, standard_tN8]

mfr2Dr, mfr2Dz = mfr2D.get_mfr_results(
        program='20181010.032',
        no_ani=4,
        kani=[2., .35],
        nVals=[13, 2],
        nigs=1,
        times=1.3,
        grid_nt=150,
        grid_nr=20,
        strgrid='sN8_30x20x150_1.35',
        base='_mfr1D',
        magconf='EIM_beta065',
        new_type=None,
        RGS=False,
        add_camera=False,
        reduced=True,
        phantom=False,
        plot=False,
        saving=False,
        debug=False)[1:3]

name = 'phi108.0_res10_conf_lin'
islands = poincare.store_read(name=name, arg='islands1_')
divertors = poincare.define_divWall(phi=108.)

def plot2D(axis, data, x=mfr2Dr, y=mfr2Dz, log=False):
    patches = []
    nr, nt = np.shape(data)
    for i in range(nr):
        for j in range(nt):
            poly = np.array([
                x[i, j], y[i, j]]).transpose()
            polygon = Polygon(poly, aa=False)
            patches.append(polygon)
    if log:
        plot = PatchCollection(patches, cmap=mpl.cm.viridis,
                               norm=mpl.colors.LogNorm())
    else:
        plot = PatchCollection(patches, cmap=mpl.cm.viridis)
    colors = data.reshape(-1) / 1.e6
    plot.set_array(colors)
    axis.add_collection(plot)

    poincare_plots.plot_div(axis=axis, points=divertors)
    poincare_plots.PlotPoincare(axis=axis, surfaces=islands)

    return (axis, plot)
# Out:
# 		\\ using own geometry input: EIM_beta065 sN8_30x20x150_1.35
# \\share.ipp-hgw.mpg.de\documents\pih\Documents\git\QSB_Bolometry\libprad
# 		\\ using own geometry input: EIM_beta065 sN8_30x20x150_1.35
# \\share.ipp-hgw.mpg.de\documents\pih\Documents\git\QSB_Bolometry\libprad
# 		\\ load islands1  (4, 15, 100) 0.05MB
# 		\\ load divertors  (4, 525, 2) 0.03MB

# %%
fig, axes = p.subplots(ncols=2, nrows=2)

titles = ['N=2', 'N=2',
          'N=4', 'N=4',
          'N=8', 'N=8']
markers = ['s', '^',
           's', '^',
           's', '^']
colors = cm.brg(np.linspace(0, 1, len(titles)))[::-1]

ehbcm, ghbcm = camera_info['channels']['eChannels']['HBCm'], \
    camera_info['channels']['gChannels']['HBCm']
evbc, gvbc = camera_info['channels']['eChannels']['VBC'], \
    camera_info['channels']['gChannels']['VBC']

i = 0
lines = []
for label, numbers in zip(titles, data):
    line, = axes[0, 0].plot(
        ghbcm,  # [13:16], 
        np.sum(numbers[6][ehbcm[:]], axis=(1, 2, 3)) * 100.**4.,
        c=colors[i], marker=markers[i], ls='-.', markersize=4., label=label)
    axes[1, 0].plot(
        ghbcm,  # [13:16],
        np.sum(numbers[2][ehbcm[:]], axis=(1)) * 100.**3,
        c=colors[i], marker=markers[i], ls='-.', markersize=4.)
    
    axes[0, 1].plot(
        gvbc,  # [:3],
        np.sum(numbers[6][evbc[:]], axis=(1, 2, 3)) * 100.**4.,
        c=colors[i], marker=markers[i], ls='-.', markersize=4.)
    axes[1, 1].plot(
        gvbc,  # [:3],
        np.sum(numbers[2][evbc[:]], axis=(1)) * 100.**3,
        c=colors[i], marker=markers[i], ls='-.', markersize=4.)

    lines.append(line)
    i += 1

for ax in [axes[0, 0], axes[0, 1]]:
    ax.set_xticklabels([])
    ax.set_ylim(
        np.min(np.sum(numbers[6][ehbcm], axis=(1, 2, 3))) * 100.**4. - 1.e-2,
        1.03 * 100.**4. * np.max(np.sum(numbers[6][evbc], axis=(1, 2, 3))))
for ax in [axes[1, 0], axes[1, 1]]:
    ax.set_xlabel('channel number [#]')
    ax.set_ylim(
        np.min(np.sum(numbers[2][ehbcm], axis=(1))) * 100.**3. - 100.,
        1.03 * 100.**3. * np.max(np.sum(numbers[2][evbc], axis=(1))))
for ax in [axes[0, 0], axes[1, 0]]:
    ax.set_xlim(ghbcm[0] - .5, ghbcm[-1] + .5)
for ax in [axes[0, 1], axes[1, 1]]:
    ax.set_xlim(gvbc[0] - .5, gvbc[-1] + .5)
    ax.set_yticklabels([])

axes[0, 0].set_ylabel('entendue [x10$^{2}$ cm$^{3}$]')
axes[1, 0].set_ylabel('volume [cm$^{3}$]')

axes[0, 0].legend(
    lines, [l.get_label() for l in lines],
    loc='upper center', bbox_to_anchor=(.5, 1.35),
    ncol=6, fancybox=True, shadow=False,
    handletextpad=0.1, labelspacing=0.2, handlelength=1.)
    
prop = dict(boxstyle='round', facecolor='lightgrey', alpha=0.5)
text = 'HBCm'
axes[0, 0].text(
    0.05, 0.8, text, transform=axes[0, 0].transAxes,
    verticalalignment='top', bbox=prop)

text = 'VBC'
axes[0, 1].text(
    0.05, 0.2, text, transform=axes[0, 1].transAxes,
    verticalalignment='top', bbox=prop)

fig.set_size_inches(9., 3.5)
fig.savefig('kfactors_volumes_interpolations_comp.pdf',
            dpi=169., bbox_inches='tight')
p.close('all')

# %%
fig, ax = p.subplots(nrows=1, ncols=2)

data = [standard_sN2, standard_tN2,
        standard_sN4, standard_tN4,
        standard_sN8, standard_tN8]

diff = np.sum(data[4][8], axis=(0, 1)) - np.sum(data[0][8], axis=(0, 1))
ax[0], plot = plot2D(axis=ax[0], data=np.abs(diff * 100.**3.), log=True)
cb = fig.colorbar(plot, ax=ax[0], shrink=0.85)
cb.set_label('etendue difference [mm$^{3}$]')

diff = np.sum(data[5][8], axis=(0, 1)) - np.sum(data[4][8], axis=(0, 1))
ax[1], plot = plot2D(axis=ax[1], data=np.abs(diff * 100.**3.), log=True)
cb = fig.colorbar(plot, ax=ax[1], shrink=0.85)
cb.set_label('etendue difference [mm$^{3}$]')

for axis in ax:
    axis.axis('off')

ax[0].set_title("$||\mathbf{T}_{N=2}-\mathbf{T}_{N=8}||_{inter.}$")
ax[1].set_title("$||\mathbf{T}_{tri.}-\mathbf{T}_{inter.}||$")

fig.set_size_inches(9., 3.)
fig.savefig('compare_emissivities3D.pdf', bbox_inches='tight', dpi=169.0)
p.close('all')

# %%
fig = p.figure()
ax = Axes3D(fig)

for i in range(30):
    p.plot(
        mesh3D[0, i, 20, :],
        mesh3D[1, i, 20, :],
        mesh3D[2, i, 20, :],
        c='lightgrey', alpha=0.5, lw=0.5)

for i in range(151):
    p.plot(
        mesh3D[0, :, 20, i],
        mesh3D[1, :, 20, i],
        mesh3D[2, :, 20, i],
        c='lightgrey', alpha=0.5, lw=0.5)

CH = camera_info['channels']['eChannels']['VBC']
nCH = camera_info['channels']['eChannels']['ARTf']
# default = standard_sN8[16]['values']
default = artificialHBCm_sN8[16]['values']

label, obj = 'newCamera_VBCm', artificials_sN8[1]
LoS = obj[16]['values']

xz = np.array([LoS['xz_plane']['range'], LoS['xz_plane']['line']])
xy = np.array([LoS['xy_plane']['range'], LoS['xy_plane']['line']])

xzd = np.array([default['xz_plane']['range'], default['xz_plane']['line']])
xyd = np.array([default['xy_plane']['range'], default['xy_plane']['line']])

for n in CH:
    r = np.array([
        np.mean(xz[:, n], axis=(1))[0],
        np.mean(xy[:, n], axis=(1))[1],
        np.mean(xz[:, n], axis=(1))[1]])
    dr = r[:, 1] - r[:, 0]
    L = np.sqrt(dr.dot(dr))

    dL = .75
    r = np.array([
        r[:, 0],
        r[:, 0] + 0.9 * dL * dr]).transpose()
    ax.plot(r[0], r[1], r[2], c='k')

    # ax.plot(
    #     np.mean(xzd[:, n], axis=(1))[0],
    #     np.mean(xyd[:, n], axis=(1))[1],
    #     np.mean(xzd[:, n], axis=(1))[1], c='k', alpha=0.75)

for n in nCH:
    r = np.array([
        np.mean(xz[:, n], axis=(1))[0],
        np.mean(xy[:, n], axis=(1))[1],
        np.mean(xz[:, n], axis=(1))[1]])
    dr = r[:, 1] - r[:, 0]
    L = np.sqrt(dr.dot(dr))

    dL = (1. - np.abs(119 - n) / 13.)
    r = np.array([
        r[:, 0],
        r[:, 0] + 0.9 * dL * dr]).transpose()
    ax.plot(r[0], r[1], r[2], c='b')

ax.set_xlim(np.min(mesh3D[0, :, 20, :]), np.max(mesh3D[0, :, 20, :]))
ax.set_ylim(np.min(mesh3D[1, :, 20, :]), np.max(mesh3D[1, :, 20, :]))
ax.set_zlim(np.min(mesh3D[2, :, 20, :]), np.max(mesh3D[2, :, 20, :]))

ax.axis('off')
ax.grid(b=None)
ax.view_init(10., -50.)

fig.set_size_inches(5., 4.)
fig.savefig('LoS_comparison_' + label + '_sN8.pdf',
            dpi=169., bbox_inches='tight')
p.close('all')

# %%
mesh2D['values']['fs'].keys()
# Out:
# dict_keys(['108.', 'HBCm', 'VBCl', 'VBCr'])

# %%
mesh2D = standard_sN8[0]
np.shape(mesh2D['values']['fs']['108.'])
# Out:
# (2, 21, 151)

# %%
r
# Out:
# array([[ 4.98566701,  3.84436343],
#        [-0.611415  ,  0.33841998]])

# %%
fig, ax = p.subplots()

mesh2D = standard_sN8[0]['values']['fs']['108.']
for i in range(21):
    ax.plot(
        mesh2D[0, i, :],
        mesh2D[1, i, :],
        c='lightgrey', alpha=0.5, lw=0.5)

for i in range(151):
    ax.plot(
        mesh2D[0, :, i],
        mesh2D[1, :, i],
        c='lightgrey', alpha=0.5, lw=0.5)

CH = camera_info['channels']['eChannels']['HBCm']
nCH = camera_info['channels']['eChannels']['ARTf']

default = standard_sN8[16]['values']
# default = artificialHBCm_sN8[16]['values']

label, obj = 'newCamera_MIRh', artificials_sN8[0]
LoS = obj[16]['values']

rz = np.array([LoS['rz_plane']['range'], LoS['rz_plane']['line']])
rzd = np.array([default['rz_plane']['range'], default['rz_plane']['line']])

for n in CH:
    r = np.array([
        np.mean(rzd[:, n], axis=(1))[0],
        np.mean(rzd[:, n], axis=(1))[1]])
    dr = r[:, 1] - r[:, 0]
    # L = np.sqrt(dr.dot(dr))

    dL = 1.1
    r = np.array([
        r[:, 0], r[:, 0] + 0.9 * dL * dr]).transpose()
    orig, = ax.plot(r[0], r[1], lw=0.66, alpha=0.75, c='k', label='HBCm')

    # ax.plot(
    #     np.mean(xzd[:, n], axis=(1))[0],
    #     np.mean(xyd[:, n], axis=(1))[1],
    #     np.mean(xzd[:, n], axis=(1))[1], c='k', alpha=0.75)

for n in nCH:
    r = np.array([
        np.mean(rz[:, n], axis=(1))[0],
        np.mean(rz[:, n], axis=(1))[1]])
    dr = r[:, 1] - r[:, 0]
    L = np.sqrt(dr.dot(dr))

    dL = (1. - np.abs(120 - n) / 13.)
    r = np.array([
        r[:, 0], r[:, 0] + 0.9 * dL * dr]).transpose()
    art, = ax.plot(r[0], r[1], lw=0.66, alpha=0.7, c='b', label='MIRh')

ax = poincare_plots.plot_div(axis=ax, points=divertors)
# ax.set_xlim(np.min(mesh2D[0, 20, :]), np.max(mesh2D[0, 20, :]))
# ax.set_ylim(np.min(mesh2D[1, 20, :]), np.max(mesh2D[1, 20, :]))

ax.axis('off')
ax.grid(b=None)

ax.legend(
    [art, orig], [l.get_label() for l in [art, orig]],
    loc='upper center', bbox_to_anchor=(.8, 0.95),
    ncol=2, fancybox=True, shadow=True,
    handletextpad=0.3, labelspacing=0.5, handlelength=1.5)

fig.set_size_inches(5., 3.)
fig.savefig('LoS_comparison_' + label + '_sN8.pdf',
            dpi=169., bbox_inches='tight')
p.close('all')

# %%
obj = errors_sN8[-1]

importlib.reload(ptl)
importlib.reload(fgp)
cp = ptl.forward_integrated_LOS(
    material='C_',
    strahl_ids=['00093', '00094'],
    labels=['f$_{rad}\\approx$90%', 'f$_{rad}\\approx$100%'],
    emissivity=obj[8], reff=obj[10], reff_LoS=obj[13],
    minor_radius=obj[12], label=obj[17],
    plot=True, debug=False)

# %%
# artificialHBCm_sN8
# centered_sN8
# symmetric_sN8
# fixedLos_sN8
# tilted_sN8
# errors_sN8

# %%
len(tilted_sN8)

# %%
np.shape(symmetric_sN8[8])
# Out:
# (128, 64, 20, 150)

# %%
fig, ax = p.subplots(nrows=1, ncols=1)

diff = np.sum(standard_sN8[8][:], axis=(0, 1)) - \
  np.sum(artificials_sN8[1][8][:], axis=(0, 1))
ax, plot = plot2D(axis=ax, data=np.abs(diff * 100.**3.) + 1.e-9, log=True)
cb = fig.colorbar(plot, ax=ax, shrink=0.85)
cb.set_label('etendue difference [mm$^{3}$]')

# for axis in ax:
ax.axis('off')

fig.set_size_inches(5., 3.)
fig.savefig('compare_VBCm_emissivities3D.pdf',
            bbox_inches='tight', dpi=169.0)
p.close('all')

# %%
importlib.reload(ptl)
importlib.reload(fgp)
importlib.reload(invert)

(mesh2D, mesh3D, raw_volume, old_volume, volume, line_sections2D,
 line_sections3D, emissivity2D, emissivity3D, factors, reff, pos_lofs,
 minor_radius, reff_LoS, geometry, interpolated, LoS, label) = invert.main(
    nPhi=30, nL=150, nFS=20, vpF=1.35, N=[4, 2], 
    VMID='EIM_000', interp_method='square',  # triang
    tilt_deg=-1., error_scale=0.0001,  # 0.1 mm (0.5 mm)  
    add_camera=False,
    new_type='VBCm',  # 'HBCm'
    artificial_HBCm=True,
    random_error=False,
    centered=False,
    fix_LoS=False,
    symmetric=False,
    tilt=False,
    plot=False,
    debug=False)

cp = ptl.forward_integrated_LOS(
    material='C_',
    strahl_ids=['00091', '00092', '00093', '00094'],
    labels=[
        'f$_{rad}$=33%', 'f$_{rad}$=66%', 'f$_{rad}$=90%', 'f$_{rad}$=100%'],
    emissivity=emissivity3D, reff=reff, reff_LoS=reff_LoS, minor_radius=minor_radius,
    label=label, plot=True, debug=False)
